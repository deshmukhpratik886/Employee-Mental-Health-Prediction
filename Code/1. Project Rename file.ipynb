# %% [markdown]
# # Data Preprocessing
# ## 1. Identify and Renaming columns

# %%
#import library pandas

import pandas as pd

# %% [markdown]
# ### 1.1 2016 data on Mental Health

# %%
#import 2016 csv file in jupyter through pandas

f1 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\
Complete record of employee mental health from 2014-2022\\
mental-heath-in-tech-2016_20161114.csv')

# %%
#show first 5 rows from csv file
f1.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %%
#show last 5 rows from csv file
f1.tail()
# Out:
#       Are you self-employed?  \
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# 1431                                            100-500
# 1432                                            100-500
#
#       Is your employer primarily a tech company/organization?  \
# 1428                                                NaN
# 1429                                                NaN
# 1430                                                1.0
# 1431                                                0.0
# 1432                                                1.0
#
#       Is your primary role within your company related to tech/IT?  \
# ...

# %% [markdown]
# Creating Data Frame

# %%
#create Data Frame 
df_f1 = pd.DataFrame(f1)

# %% [markdown]
# Creating the Dictionary for 2016 file

# %%
#creat dictionary

dict = {'Are you self-employed?':'Self_Employed',
        'How many employees does your company or organization have?':'No_of_Employees',
        'Is your employer primarily a tech company/organization?':'Tech_Company',
        'Is your primary role within your company related to tech/IT?':'A',
        'Does your employer provide mental health benefits as part of healthcare coverage?':'Benefits',
        'Do you know the options for mental health care available under your employer-provided coverage?':'C',
        'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
        'Does your employer offer resources to learn more about mental health concerns and options for seeking help?':'seeking help',
        'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
        'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:':'Medical_Leave',
        'Do you think that discussing a mental health disorder with your employer would have negative consequences?':'mental_health_consequence',
        'Do you think that discussing a physical health issue with your employer would have negative consequences?':'phys_health_consequence',
        'Would you feel comfortable discussing a mental health disorder with your coworkers?':'discussed_with_employer',
        'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?':'supervisor',
        'Do you feel that your employer takes mental health as seriously as physical health?':'issue_discussing',
        'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?':'obs_consequence',
        'Do you have medical coverage (private insurance or state-provided) which includes treatment of \xa0mental health issues?':'Medical_Insurence',
        'Do you know local or online resources to seek help for a mental health disorder?':'J',
        'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?':'L',
        'If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?':'M',
        'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?':'N',
        'If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?':'O',
        'Do you believe your productivity is ever affected by a mental health issue?':'P',
        'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'Q',
        'Do you have previous employers?':'R',
        'Have your previous employers provided mental health benefits?':'S',
        'Were you aware of the options for mental health care provided by your previous employers?':'T',
        'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'U',
        'Did your previous employers provide resources to learn more about mental health issues and how to seek help?':'seek_help',
        'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'V',
        'Do you think that discussing a mental health disorder with previous employers would have negative consequences?':'W',
        'Do you think that discussing a physical health issue with previous employers would have negative consequences?':'X',
        'Would you have been willing to discuss a mental health issue with your previous co-workers?':'Y',
        'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?':'Z',
        'Did you feel that your previous employers took mental health as seriously as physical health?':'AA',
        'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?':'AB',
        'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
        'Why or why not?':'AD',
        'Would you bring up a mental health issue with a potential employer in an interview?':'a mental potential',
        'Why or why not?':'AF',
        'Do you feel that being identified as a person with a mental health issue would hurt your career?':'AG',
        'Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?':'AH',
        'How willing would you be to share with friends and family that you have a mental illness?':'share with friends and family',
        'Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?':'unsupportive_workplace',
        'Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?':'AJ',
        'Do you have a family history of mental illness?':'Family_Histroy',
        'Have you had a mental health disorder in the past?':'Past_mental_Health',
        'Do you currently have a mental health disorder?':'have_a_mental_Health',
        'If yes, what condition(s) have you been diagnosed with?':'AN',
        'If maybe, what condition(s) do you believe you have?':'AO',
        'Have you been diagnosed with a mental health condition by a medical professional?':'treated_Mental_Health(Diagnosed)',
        'If so, what condition(s) were you diagnosed with?':'AP',
        'Have you ever sought treatment for a mental health issue from a mental health professional?':'Treatment',
        'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?':'before_Interfere_in_work',
        'If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?':'after_Interfere_in_work',
        'What is your age?':'Age',
        'What is your gender?':'Gender',
        'What country do you live in?':'Country',
        'What US state or territory do you live in?':'State',
        'What country do you work in?':'work in country',
        'What US state or territory do you work in?':'work in state',
        'Which of the following best describes your work position?':'AS',
        'Do you work remotely?':'remote_work'
       
       }

# %% [markdown]
# Renaming the columns using Dictionary

# %%
df_f1.rename(columns=dict,
          inplace=True)

# %% [markdown]
# show Columns rename

# %%
# list(data) or showing the column name of dataframe

list(df_f1.columns)
# Out:
# ['Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'A',
#  'Benefits',
#  'C',
#  'formally_discusse_employer',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'discussed_with_employer',
#  'supervisor',
#  'issue_discussing',
#  'obs_consequence',
#  'Medical_Insurence',
#  'J',
#  'L',
#  'M',
#  'N',
#  'O',
#  'P',
#  'Q',
#  'R',
#  'S',
#  'T',
#  'U',
#  'seek_help',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'a physical potential',
#  'AF',
#  'a mental potential',
#  'Why or why not?.1',
#  'AG',
#  'AH',
#  'share with friends and family',
#  'unsupportive_workplace',
#  'AJ',
#  'Family_Histroy',
#  'Past_mental_Health',
#  'have_a_mental_Health',
#  'AN',
#  'AO',
#  'treated_Mental_Health(Diagnosed)',
#  'AP',
#  'Treatment',
#  'before_Interfere_in_work',
#  'after_Interfere_in_work',
#  'Age',
#  'Gender',
#  'Country',
#  'State',
#  'work in country',
# ...

# %%
df_f1.head()
# Out:
#    Self_Employed No_of_Employees  Tech_Company    A  \
# 0              0          26-100           1.0  NaN
# 1              0            6-25           1.0  NaN
# 2              0            6-25           1.0  NaN
# 3              1             NaN           NaN  NaN
# 4              0            6-25           0.0  1.0
#
#                           Benefits    C formally_discusse_employer  \
# 0  Not eligible for coverage / N/A  NaN                         No
# 1                               No  Yes                        Yes
# 2                               No  NaN                         No
# 3                              NaN  NaN                        NaN
# 4                              Yes  Yes                         No
#
#   seeking help     anonymity               Medical_Leave  ...  \
# 0           No  I don't know                   Very easy  ...
# 1          Yes           Yes               Somewhat easy  ...
# ...

# %% [markdown]
# **Save the data in Local File (2016 File)**

# %%
#Export the DataFrame file in CSV file 2016

df_f1.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\mental-heath-in-tech-2016_20161114.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.2 2020 data on Mental Health

# %%
#import 2020 csv file in jupyter through pandas

f2 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2020.csv')

# %%
 f2.head()
# Out:
#                                   #  *Are you self-employed?*  \
# 0  zwrffw6ykfo82ft1twvzwrffw6c6wsfv                         1
# 1  zhdmhaa8r0125c4zmoi7qzhdmtjrakhm                         1
# 2  x4itwa9hnlw7qke4y5xibx4itwa9yzl5                         1
# 3  x3v3oimu5pn0043n8x3v3oizaybhwwto                         1
# 4  uyp6re7bhnyx6gez09uyp6re72z0e4e4                         1
#
#   How many employees does your company or organization have?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
list(f2.columns)
# Out:
# ['#',
#  '*Are you self-employed?*',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
#create Data Frame 
df_f2 = pd.DataFrame(f2)

# %%
dict2 = {
    '#':'NO',
 '*Are you self-employed?*':'Self_Employed',
 'How many employees does your company or organization have?':'No_of_Employees',
 'Is your employer primarily a tech company/organization?':'Tech_Company',
 'Is your primary role within your company related to tech/IT?':'B',
 'Does your employer provide mental health benefits as part of healthcare coverage?':'C',
 'Do you know the options for mental health care available under your employer-provided health coverage?':'D',
 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
 'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':'seeking help',
 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
 'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':'Medical_Leave',
 'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':'talking_to_coworker',
 'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':'supervisor',
 'Have you ever discussed your mental health with your employer?':'discussed_with_employer',
 'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.':'E',
 'Would you feel comfortable discussing a mental health issue with your coworkers?':'issue_discussing',
 'Have you ever discussed your mental health with coworkers?':'discusssed_coworkers',
 'Describe the conversation with coworkers you had about your mental health including their reactions.':'F',
 "Have you ever had a coworker discuss their or another coworker's mental health with you?":"G",
 'Describe the conversation your coworker had with you about their mental health (please do not use names).':'I',
 'Overall, how much importance does your employer place on physical health?':'physical_health_importance',
 'Overall, how much importance does your employer place on mental health?':'Mental_health_importance',
 'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?':'Medical_Insurence',
 'Do you know local or online resources to seek help for a mental health issue?':'J',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?':'K',
 'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?':'L',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?':'M',
 'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?':'N',
 'Do you believe your productivity is ever affected by a mental health issue?':'impact_on_Productivity',
 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'O',
 '*Do you have previous employers?*':'P',
 'Was your employer primarily a tech company/organization?':'tech_company',
 'Have your previous employers provided mental health benefits?':'Q',
 'Were you aware of the options for mental health care provided by your previous employers?':'Mental_health_Aware',
 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'R',
 'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':'S',
 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'T',
 'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':'U',
 'Would you have been willing to discuss your mental health with your direct supervisor(s)?':'V',
 'Did you ever discuss your mental health with your previous employer?':'W',
 'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.':'X',
 'Would you have been willing to discuss your mental health with your coworkers at previous employers?':'Y',
 'Did you ever discuss your mental health with a previous coworker(s)?':'Z',
 'Describe the conversation you had with your previous coworkers about your mental health including their reactions.':'AA',
 "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":'AB',
 'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':'AC',
 'Overall, how much importance did your previous employer place on physical health?':'AD',
 'Overall, how much importance did your previous employer place on mental health?':'AE',
 'Do you *currently* have a mental health disorder?':'have_a_mental_Health',
 'Have you ever been *diagnosed* with a mental health disorder?':'treated_Mental_Health(Diagnosed)',
 'Anxiety Disorder (Generalized, Social, Phobia, etc)':'AF',
 'Mood Disorder (Depression, Bipolar Disorder, etc)':'AG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)':'AH',
 'Eating Disorder (Anorexia, Bulimia, etc)':'AI',
 'Attention Deficit Hyperactivity Disorder':'AJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)':'AK',
 'Obsessive-Compulsive Disorder':'AL',
 'Post-Traumatic Stress Disorder':'AM',
 'Stress Response Syndromes':'AN',
 'Dissociative Disorder':'AO',
 'Substance Use Disorder':'AP',
 'Addictive Disorder':'AQ',
 'Other':'AR',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).1':'AS',
 'Mood Disorder (Depression, Bipolar Disorder, etc).1':'AT',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1':'AU',
 'Eating Disorder (Anorexia, Bulimia, etc).1':'AV',
 'Attention Deficit Hyperactivity Disorder.1':'AW',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1':'AX',
 'Obsessive-Compulsive Disorder.1':'AY',
 'Post-traumatic Stress Disorder':'AZ',
 'Stress Response Syndromes.1':'BA',
 'Dissociative Disorder.1':'BB',
 'Substance Use Disorder.1':'BC',
 'Addictive Disorder.1':'BD',
 'Other.1':'BE',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).2':'BF',
 'Mood Disorder (Depression, Bipolar Disorder, etc).2':'BG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2':'BH',
 'Eating Disorder (Anorexia, Bulimia, etc).2':'BI',
 'Attention Deficit Hyperactivity Disorder.2':'BJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2':'BK',
 'Obsessive-Compulsive Disorder.2':'BL',
 'Post-traumatic Stress Disorder.1':'BM',
 'Stress Response Syndromes.2':'BN',
 'Dissociative Disorder.2':'BO',
 'Substance Use Disorder.2':'BP',
 'Addictive Disorder.2':'BQ',
 'Other.2':'BR',
 'Have you had a mental health disorder in the past?':'Past_mental_Health',
 'Have you ever sought treatment for a mental health disorder from a mental health professional?':'Treatment',
 'Do you have a family history of mental illness?':'family history',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*':'after_Interfere_in_work',
 'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':'Stress_Syndromes',
 'How willing would you be to share with friends and family that you have a mental illness?':'share with friends and family',
 'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
 'Why or why not?':'BS',
 'Would you bring up your *mental* health with a potential employer in an interview?':'a mental potential',
 'Why or why not?.1':'BT',
 'Are you openly identified at work as a person with a mental health issue?':'openly_identify',
 'Has being identified as a person with a mental health issue affected your career?':'BU',
 'How has it affected your career?':'BV',
 'If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?':'co-workers reaction',
 'Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?':'unsupportive workplace',
 'Describe the circumstances of the badly handled or unsupportive response.':'BW',
 'Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?':'supportive workplace',
 'Describe the circumstances of the supportive or well handled response.':'BX',
 'Overall, how well do you think the tech industry supports employees with mental health issues?':'tech industry support',
 'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.':'BY',
 'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.':'BZ',
 'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)':'talk about experience',
 'What is your age?':'Age',
 'What is your gender?':'Gender',
 'What country do you *live* in?':'Country',
 'What US state or territory do you *live* in?':'State',
 'What is your race?':'race',
 'Other.3':'CA',
 'What country do you *work* in?':'work in country',
 'What US state or territory do you *work* in?':'work in state'
}

# %%
df_f2.rename(columns=dict2,
          inplace=True)

# %%
list(df_f2.columns)
# Out:
# ['NO',
#  'Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'B',
#  'C',
#  'D',
#  'formally_discusse_employer',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'talking_to_coworker',
#  'supervisor',
#  'discussed_with_employer',
#  'E',
#  'issue_discussing',
#  'discusssed_coworkers',
#  'F',
#  'G',
#  'I',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'Medical_Insurence',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'impact_on_Productivity',
#  'O',
#  'P',
#  'tech_company',
#  'Q',
#  'Mental_health_Aware',
#  'R',
#  'S',
#  'T',
#  'U',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'AC',
#  'AD',
#  'AE',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'AF',
#  'AG',
#  'AH',
#  'AI',
#  'AJ',
#  'AK',
#  'AL',
#  'AM',
#  'AN',
#  'AO',
#  'AP',
#  'AQ',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AV',
#  'AW',
#  'AX',
#  'AY',
#  'AZ',
#  'BA',
#  'BB',
#  'BC',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
# ...

# %% [markdown]
# **Save the data in Local File (2020 File)**

# %%
#Export the DataFrame file in CSV file 2020

df_f2.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2020.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.3 2021 data on Mental Health

# %%
#import 2021 csv file in jupyter through pandas
bvfrrr
f3 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2021.csv')

# %%
 f3.head()
# Out:
#                                   #  *Are you self-employed?*  \
# 0  eu6sxt9r6pyxxykpxcqs6r2qeu6sxt9r                         0
# 1  mqgsjpmc31k0fuymqgv96vapalozx3q0                         0
# 2  fkuijv5hpifz4fusbn1fkuib4ipqt19s                         0
# 3  eb7i5ye61yizgs5veb7i5yyttqp5zwp2                         1
# 4  0qoaw3bb3kzbb2oet0qoa3xc3yzdrvva                         0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                           500-1000
# 2                                            100-500
# 3                                                NaN
# 4                                     More than 1000
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# ...

# %%
list(f3.columns)
# Out:
# ['#',
#  '*Are you self-employed?*',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
dict3 = {
   '#':'NO',
 '*Are you self-employed?*':'Self_Employed',
 'How many employees does your company or organization have?':'No_of_Employees',
 'Is your employer primarily a tech company/organization?':'Tech_Company',
 'Is your primary role within your company related to tech/IT?':'B',
 'Does your employer provide mental health benefits as part of healthcare coverage?':'C',
 'Do you know the options for mental health care available under your employer-provided health coverage?':'D',
 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
 'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':'seeking help',
 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
 'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':'Medical_Leave',
 'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':'talking_to_coworker',
 'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':'supervisor',
 'Have you ever discussed your mental health with your employer?':'discussed_with_employer',
 'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.':'E',
 'Would you feel comfortable discussing a mental health issue with your coworkers?':'issue_discussing',
 'Have you ever discussed your mental health with coworkers?':'discusssed_coworkers',
 'Describe the conversation with coworkers you had about your mental health including their reactions.':'F',
 "Have you ever had a coworker discuss their or another coworker's mental health with you?":"G",
 'Describe the conversation your coworker had with you about their mental health (please do not use names).':'I',
 'Overall, how much importance does your employer place on physical health?':'physical_health_importance',
 'Overall, how much importance does your employer place on mental health?':'Mental_health_importance',
 'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?':'Medical_Insurence',
 'Do you know local or online resources to seek help for a mental health issue?':'J',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?':'K',
 'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?':'L',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?':'M',
 'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?':'N',
 'Do you believe your productivity is ever affected by a mental health issue?':'impact_on_Productivity',
 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'O',
 '*Do you have previous employers?*':'P',
 'Was your employer primarily a tech company/organization?':'tech_company',
 'Have your previous employers provided mental health benefits?':'Q',
 'Were you aware of the options for mental health care provided by your previous employers?':'Mental_health_Aware',
 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'R',
 'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':'S',
 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'T',
 'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':'U',
 'Would you have been willing to discuss your mental health with your direct supervisor(s)?':'V',
 'Did you ever discuss your mental health with your previous employer?':'W',
 'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.':'X',
 'Would you have been willing to discuss your mental health with your coworkers at previous employers?':'Y',
 'Did you ever discuss your mental health with a previous coworker(s)?':'Z',
 'Describe the conversation you had with your previous coworkers about your mental health including their reactions.':'AA',
 "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":'AB',
 'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':'AC',
 'Overall, how much importance did your previous employer place on physical health?':'AD',
 'Overall, how much importance did your previous employer place on mental health?':'AE',
 'Do you *currently* have a mental health disorder?':'have_a_mental_Health',
 'Have you ever been *diagnosed* with a mental health disorder?':'treated_Mental_Health(Diagnosed)',
 'Anxiety Disorder (Generalized, Social, Phobia, etc)':'AF',
 'Mood Disorder (Depression, Bipolar Disorder, etc)':'AG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)':'AH',
 'Eating Disorder (Anorexia, Bulimia, etc)':'AI',
 'Attention Deficit Hyperactivity Disorder':'AJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)':'AK',
 'Obsessive-Compulsive Disorder':'AL',
 'Post-Traumatic Stress Disorder':'AM',
 'Stress Response Syndromes':'AN',
 'Dissociative Disorder':'AO',
 'Substance Use Disorder':'AP',
 'Addictive Disorder':'AQ',
 'Other':'AR',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).1':'AS',
 'Mood Disorder (Depression, Bipolar Disorder, etc).1':'AT',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1':'AU',
 'Eating Disorder (Anorexia, Bulimia, etc).1':'AV',
 'Attention Deficit Hyperactivity Disorder.1':'AW',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1':'AX',
 'Obsessive-Compulsive Disorder.1':'AY',
 'Post-traumatic Stress Disorder':'AZ',
 'Stress Response Syndromes.1':'BA',
 'Dissociative Disorder.1':'BB',
 'Substance Use Disorder.1':'BC',
 'Addictive Disorder.1':'BD',
 'Other.1':'BE',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).2':'BF',
 'Mood Disorder (Depression, Bipolar Disorder, etc).2':'BG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2':'BH',
 'Eating Disorder (Anorexia, Bulimia, etc).2':'BI',
 'Attention Deficit Hyperactivity Disorder.2':'BJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2':'BK',
 'Obsessive-Compulsive Disorder.2':'BL',
 'Post-traumatic Stress Disorder.1':'BM',
 'Stress Response Syndromes.2':'BN',
 'Dissociative Disorder.2':'BO',
 'Substance Use Disorder.2':'BP',
 'Addictive Disorder.2':'BQ',
 'Other.2':'BR',
 'Have you had a mental health disorder in the past?':'Past_mental_Health',
 'Have you ever sought treatment for a mental health disorder from a mental health professional?':'Treatment',
 'Do you have a family history of mental illness?':'family history',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*':'after_Interfere_in_work',
 'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':'Stress_Syndromes',
 'How willing would you be to share with friends and family that you have a mental illness?':'share with friends and family',
 'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
 'Why or why not?':'BS',
 'Would you bring up your *mental* health with a potential employer in an interview?':'a mental potential',
 'Why or why not?.1':'BT',
 'Are you openly identified at work as a person with a mental health issue?':'openly_identify',
 'Has being identified as a person with a mental health issue affected your career?':'BU',
 'How has it affected your career?':'BV',
 'If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?':'co-workers reaction',
 'Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?':'unsupportive workplace',
 'Describe the circumstances of the badly handled or unsupportive response.':'BW',
 'Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?':'supportive workplace',
 'Describe the circumstances of the supportive or well handled response.':'BX',
 'Overall, how well do you think the tech industry supports employees with mental health issues?':'tech industry support',
 'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.':'BY',
 'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.':'BZ',
 'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)':'talk about experience',
 'What is your age?':'Age',
 'What is your gender?':'Gender',
 'What country do you *live* in?':'Country',
 'What US state or territory do you *live* in?':'State',
 'What is your race?':'race',
 'Other.3':'CA',
 'What country do you *work* in?':'work in country',
 'What US state or territory do you *work* in?':'work in state',
    'Have you been diagnosed with COVID-19?':'CB',
 'Start Date (UTC)':'CC',
 'Submit Date (UTC)':'CD',
 'Network ID':'CE'
}

# %%
#create Data Frame 
df_f3 = pd.DataFrame(f3)


df_f3.rename(columns=dict3,
          inplace=True)

# %%
list(df_f3.columns)
# Out:
# ['NO',
#  'Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'B',
#  'C',
#  'D',
#  'formally_discusse_employer',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'talking_to_coworker',
#  'supervisor',
#  'discussed_with_employer',
#  'E',
#  'issue_discussing',
#  'discusssed_coworkers',
#  'F',
#  'G',
#  'I',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'Medical_Insurence',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'impact_on_Productivity',
#  'O',
#  'P',
#  'tech_company',
#  'Q',
#  'Mental_health_Aware',
#  'R',
#  'S',
#  'T',
#  'U',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'AC',
#  'AD',
#  'AE',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'AF',
#  'AG',
#  'AH',
#  'AI',
#  'AJ',
#  'AK',
#  'AL',
#  'AM',
#  'AN',
#  'AO',
#  'AP',
#  'AQ',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AV',
#  'AW',
#  'AX',
#  'AY',
#  'AZ',
#  'BA',
#  'BB',
#  'BC',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
# ...

# %% [markdown]
# **Save the data in Local File (2021 File)**

# %%
#Export the DataFrame file in CSV file 2021

df_f3.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2021.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.4 2018 data on Mental Health

# %%
#import 2018 csv file in jupyter through pandas

f4 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2018.csv')

f4.head()
# Out:
#                                   #  <strong>Are you self-employed?</strong>  \
# 0  e44a0a34f2465940beda2a1537e9b99e                                        0
# 1  0d698e3beca20fb75f19b9d528e36d73                                        0
# 2  61a40c9071eb36fa9caa254d31500c41                                        0
# 3  f8624340bead7deb08abb766704ddf6b                                        0
# 4  31d3ae93b68d79e504a0a643601b6b1e                                        0
#
#   How many employees does your company or organization have?  \
# 0                                     More than 1000
# 1                                     More than 1000
# 2                                               6-25
# 3                                               6-25
# 4                                             26-100
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# ...

# %%
list(f4.columns)
# Out:
# ['#',
#  '<strong>Are you self-employed?</strong>',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
dict4 = {
   '#':'NO',
 '<strong>Are you self-employed?</strong>':'Self_Employed',
 'How many employees does your company or organization have?':'No_of_Employees',
 'Is your employer primarily a tech company/organization?':'Tech_Company',
 'Is your primary role within your company related to tech/IT?':'B',
 'Does your employer provide mental health benefits as part of healthcare coverage?':'C',
 'Do you know the options for mental health care available under your employer-provided health coverage?':'D',
 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
 'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':'seeking help',
 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
 'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':'Medical_Leave',
 'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':'talking_to_coworker',
 'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':'supervisor',
 'Have you ever discussed your mental health with your employer?':'discussed_with_employer',
 'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.':'E',
 'Would you feel comfortable discussing a mental health issue with your coworkers?':'issue_discussing',
 'Have you ever discussed your mental health with coworkers?':'discusssed_coworkers',
 'Describe the conversation with coworkers you had about your mental health including their reactions.':'F',
 "Have you ever had a coworker discuss their or another coworker's mental health with you?":"G",
 'Describe the conversation your coworker had with you about their mental health (please do not use names).':'I',
 'Overall, how much importance does your employer place on physical health?':'physical_health_importance',
 'Overall, how much importance does your employer place on mental health?':'Mental_health_importance',
 'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?':'Medical_Insurence',
 'Do you know local or online resources to seek help for a mental health issue?':'J',
 '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>':'K',
 'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?':'L',
 '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>':'M',
 'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?':'N',
 'Do you believe your productivity is ever affected by a mental health issue?':'impact_on_Productivity',
 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'O',
 '<strong>Do you have previous employers?</strong>':'P',
 'Was your employer primarily a tech company/organization?':'tech_company',
 '<strong>Have your previous employers provided mental health benefits?</strong>':'Q',
 '<strong>Were you aware of the options for mental health care provided by your previous employers?</strong>':'Mental_health_Aware',
 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'R',
 'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':'S',
 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'T',
 'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':'U',
 'Would you have been willing to discuss your mental health with your direct supervisor(s)?':'V',
 'Did you ever discuss your mental health with your previous employer?':'W',
 'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.':'X',
 '<strong>Would you have been willing to discuss your mental health with your coworkers at previous employers?</strong>':'Y',
 'Did you ever discuss your mental health with a previous coworker(s)?':'Z',
 'Describe the conversation you had with your previous coworkers about your mental health including their reactions.':'AA',
 "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":'AB',
 'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':'AC',
 'Overall, how much importance did your previous employer place on physical health?':'AD',
 'Overall, how much importance did your previous employer place on mental health?':'AE',
 'Do you currently have a mental health disorder?':'have_a_mental_Health',
 'Have you ever been diagnosed with a mental health disorder?':'treated_Mental_Health(Diagnosed)',
 'Anxiety Disorder (Generalized, Social, Phobia, etc)':'AF',
 'Mood Disorder (Depression, Bipolar Disorder, etc)':'AG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)':'AH',
 'Eating Disorder (Anorexia, Bulimia, etc)':'AI',
 'Attention Deficit Hyperactivity Disorder':'AJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)':'AK',
 'Obsessive-Compulsive Disorder':'AL',
 'Post-Traumatic Stress Disorder':'AM',
 'Stress Response Syndromes':'AN',
 'Dissociative Disorder':'AO',
 'Substance Use Disorder':'AP',
 'Addictive Disorder':'AQ',
 'Other':'AR',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).1':'AS',
 'Mood Disorder (Depression, Bipolar Disorder, etc).1':'AT',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1':'AU',
 'Eating Disorder (Anorexia, Bulimia, etc).1':'AV',
 'Attention Deficit Hyperactivity Disorder.1':'AW',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1':'AX',
 'Obsessive-Compulsive Disorder.1':'AY',
 'Post-traumatic Stress Disorder':'AZ',
 'Stress Response Syndromes.1':'BA',
 'Dissociative Disorder.1':'BB',
 'Substance Use Disorder.1':'BC',
 'Addictive Disorder.1':'BD',
 'Other.1':'BE',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).2':'BF',
 'Mood Disorder (Depression, Bipolar Disorder, etc).2':'BG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2':'BH',
 'Eating Disorder (Anorexia, Bulimia, etc).2':'BI',
 'Attention Deficit Hyperactivity Disorder.2':'BJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2':'BK',
 'Obsessive-Compulsive Disorder.2':'BL',
 'Post-traumatic Stress Disorder.1':'BM',
 'Stress Response Syndromes.2':'BN',
 'Dissociative Disorder.2':'BO',
 'Substance Use Disorder.2':'BP',
 'Addictive Disorder.2':'BQ',
 'Other.2':'BR',
 'Have you had a mental health disorder in the past?':'Past_mental_Health',
 'Have you ever sought treatment for a mental health disorder from a mental health professional?':'Treatment',
 'Do you have a family history of mental illness?':'family history',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*':'after_Interfere_in_work',
 'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':'Stress_Syndromes',
 'How willing would you be to share with friends and family that you have a mental illness?':'share with friends and family',
 'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
 'Why or why not?':'BS',
 'Would you bring up your mental health with a potential employer in an interview?':'a mental potential',
 'Why or why not?.1':'BT',
 'Are you openly identified at work as a person with a mental health issue?':'openly_identify',
 'Has being identified as a person with a mental health issue affected your career?':'BU',
 'How has it affected your career?':'BV',
 'If they knew you suffered from a mental health disorder, how do you think that team members/co-workers would react?':'co-workers reaction',
 '<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>':'unsupportive workplace',
 'Describe the circumstances of the badly handled or unsupportive response.':'BW',
 '<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>':'supportive workplace',
 'Describe the circumstances of the supportive or well handled response.':'BX',
 'Overall, how well do you think the tech industry supports employees with mental health issues?':'tech industry support',
 'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.':'BY',
 'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.':'BZ',
 'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em> and only with your permission.)':'talk about experience',
 'What is your age?':'Age',
 'What is your gender?':'Gender',
 'What country do you <strong>live</strong> in?':'Country',
 'What US state or territory do you <strong>live</strong> in?':'State',
 'What is your race?':'race',
 'Other.3':'CA',
 'What country do you <strong>work</strong> in?':'work in country',
 'What US state or territory do you <strong>work</strong> in?':'work in state',
 'Start Date (UTC)':'CC',
 'Submit Date (UTC)':'CD',
 'Network ID':'CE'
}

# %%
#create Data Frame 
df_f4 = pd.DataFrame(f4)


df_f4.rename(columns=dict4,
          inplace=True)

# %%
dict5 = {'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when being treated effectively?</strong>':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when</strong> <em><strong>NOT</strong></em><strong> being treated effectively (i.e., when you are experiencing symptoms)?</strong>':'after_Interfere_in_work'
        }

df_f4.rename(columns=dict5,
          inplace=True)

# %%
list(df_f4.columns)
# Out:
# ['NO',
#  'Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'B',
#  'C',
#  'D',
#  'formally_discusse_employer',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'talking_to_coworker',
#  'supervisor',
#  'discussed_with_employer',
#  'E',
#  'issue_discussing',
#  'discusssed_coworkers',
#  'F',
#  'G',
#  'I',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'Medical_Insurence',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'impact_on_Productivity',
#  'O',
#  'P',
#  'tech_company',
#  'Q',
#  'Mental_health_Aware',
#  'R',
#  'S',
#  'T',
#  'U',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'AC',
#  'AD',
#  'AE',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'AF',
#  'AG',
#  'AH',
#  'AI',
#  'AJ',
#  'AK',
#  'AL',
#  'AM',
#  'AN',
#  'AO',
#  'AP',
#  'AQ',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AV',
#  'AW',
#  'AX',
#  'AY',
#  'AZ',
#  'BA',
#  'BB',
#  'BC',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
# ...

# %% [markdown]
# **Save the data in Local File (2018 File)**

# %%
#Export the DataFrame file in CSV file 2018

df_f4.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2018.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.5 2017 data on Mental Health

# %%
#import 2017 csv file in jupyter through pandas

f5 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2017.csv')

f5.head()
# Out:
#                                   #  <strong>Are you self-employed?</strong>  \
# 0  e49fe87572831232dcfa51b376b22039                                        0
# 1  a1eede444ac024928d247a8372d54931                                        0
# 2  37d3fd67f62bd1e0a2dea4f9cd440d98                                        0
# 3  519b759442c1cab0e9b5a8a1acb1b216                                        0
# 4  ef0af4927b575b1a3e607c11ca37870e                                        1
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                     More than 1000
# 4                                                NaN
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# ...

# %%
list(f5.columns)
# Out:
# ['#',
#  '<strong>Are you self-employed?</strong>',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits\xa0as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
dict5 = {
   '#':'NO',
 '<strong>Are you self-employed?</strong>':'Self_Employed',
 'How many employees does your company or organization have?':'No_of_Employees',
 'Is your employer primarily a tech company/organization?':'Tech_Company',
 'Is your primary role within your company related to tech/IT?':'B',
 'Does your employer provide mental health benefits\xa0as part of healthcare coverage?':'C',
 'Do you know the options for mental health care available under your employer-provided health coverage?':'D',
 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
 'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':'seeking help',
 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
 'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':'Medical_Leave',
 'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':'talking_to_coworker',
 'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':'supervisor',
 'Have you ever discussed your mental health with your employer?':'discussed_with_employer',
 'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.':'E',
 'Would you feel comfortable discussing a mental health issue with your coworkers?':'issue_discussing',
 'Have you ever discussed your mental health with coworkers?':'discusssed_coworkers',
 'Describe the conversation with coworkers you had about your mental health including their reactions.':'F',
 "Have you ever had a coworker discuss their or another coworker's mental health with you?":"G",
 'Describe the conversation your coworker had with you about their mental health (please do not use names).':'I',
 'Overall, how much importance does your employer place on physical health?':'physical_health_importance',
 'Overall, how much importance does your employer place on mental health?':'Mental_health_importance',
 'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?':'Medical_Insurence',
 'Do you know local or online resources to seek help for a mental health issue?':'J',
 '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>':'K',
 'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?':'L',
 '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>':'M',
 'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?':'N',
 'Do you believe your productivity is ever affected by a mental health issue?':'impact_on_Productivity',
 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'O',
 '<strong>Do you have previous employers?</strong>':'P',
 'Was your employer primarily a tech company/organization?':'tech_company',
 '<strong>Have your previous employers provided mental health benefits?</strong>':'Q',
 '<strong>Were you aware of the options for mental health care provided by your previous employers?</strong>':'Mental_health_Aware',
 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'R',
 'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':'S',
 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'T',
 'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':'U',
 'Would you have been willing to discuss your mental health with your direct supervisor(s)?':'V',
 'Did you ever discuss your mental health with your previous employer?':'W',
 'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.':'X',
 '<strong>Would you have been willing to discuss your mental health with your coworkers at previous employers?</strong>':'Y',
 'Did you ever discuss your mental health with a previous coworker(s)?':'Z',
 'Describe the conversation you had with your previous coworkers about your mental health including their reactions.':'AA',
 "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":'AB',
 'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':'AC',
 'Overall, how much importance did your previous employer place on physical health?':'AD',
 'Overall, how much importance did your previous employer place on mental health?':'AE',
 'Do you currently have a mental health disorder?':'have_a_mental_Health',
 'Have you ever been diagnosed with a mental health disorder?':'treated_Mental_Health(Diagnosed)',
 'Anxiety Disorder (Generalized, Social, Phobia, etc)':'AF',
 'Mood Disorder (Depression, Bipolar Disorder, etc)':'AG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)':'AH',
 'Eating Disorder (Anorexia, Bulimia, etc)':'AI',
 'Attention Deficit Hyperactivity Disorder':'AJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)':'AK',
 'Obsessive-Compulsive Disorder':'AL',
 'Post-Traumatic Stress Disorder':'AM',
 'Stress Response Syndromes':'AN',
 'Dissociative Disorder':'AO',
 'Substance Use Disorder':'AP',
 'Addictive Disorder':'AQ',
 'Other':'AR',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).1':'AS',
 'Mood Disorder (Depression, Bipolar Disorder, etc).1':'AT',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1':'AU',
 'Eating Disorder (Anorexia, Bulimia, etc).1':'AV',
 'Attention Deficit Hyperactivity Disorder.1':'AW',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1':'AX',
 'Obsessive-Compulsive Disorder.1':'AY',
 'Post-traumatic Stress Disorder':'AZ',
 'Stress Response Syndromes.1':'BA',
 'Dissociative Disorder.1':'BB',
 'Substance Use Disorder.1':'BC',
 'Addictive Disorder.1':'BD',
 'Other.1':'BE',
 'Anxiety Disorder (Generalized, Social, Phobia, etc).2':'BF',
 'Mood Disorder (Depression, Bipolar Disorder, etc).2':'BG',
 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2':'BH',
 'Eating Disorder (Anorexia, Bulimia, etc).2':'BI',
 'Attention Deficit Hyperactivity Disorder.2':'BJ',
 'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2':'BK',
 'Obsessive-Compulsive Disorder.2':'BL',
 'Post-traumatic Stress Disorder.1':'BM',
 'Stress Response Syndromes.2':'BN',
 'Dissociative Disorder.2':'BO',
 'Substance Use Disorder.2':'BP',
 'Addictive Disorder.2':'BQ',
 'Other.2':'BR',
 'Have you had a mental health disorder in the past?':'Past_mental_Health',
 'Have you ever sought treatment for a mental health disorder from a mental health professional?':'Treatment',
 'Do you have a family history of mental illness?':'family history',
 'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when being treated effectively?</strong>':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when <em>NOT</em> being treated effectively (i.e., when you are experiencing symptoms)?</strong>':'after_Interfere_in_work',
 'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':'Stress_Syndromes',
 'How willing would you be to share with friends and family that you have a mental illness?':'share with friends and family',
 'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
 'Why or why not?':'BS',
 'Would you bring up your mental health with a potential employer in an interview?':'a mental potential',
 'Why or why not?.1':'BT',
 'Are you openly identified at work as a person with a mental health issue?':'openly_identify',
 'Has being identified as a person with a mental health issue affected your career?':'BU',
 'How has it affected your career?':'BV',
 'If they knew you suffered from a mental health disorder,\xa0how do you think that team members/co-workers would react?':'co-workers reaction',
 '<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>':'unsupportive workplace',
 'Describe the circumstances of the badly handled or unsupportive response.':'BW',
 '<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>':'supportive workplace',
 'Describe the circumstances of the supportive or well handled response.':'BX',
 'Overall, how well do you think the tech industry supports employees with mental health issues?':'tech industry support',
 'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.':'BY',
 'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.':'BZ',
 'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em>\xa0and only with your permission.)':'talk about experience',
 'What is your age?':'Age',
 'What is your gender?':'Gender',
 'What country do you <strong>live</strong> in?':'Country',
 'What US state or territory do you <strong>live</strong> in?':'State',
 'What is your race?':'race',
 'Other.3':'CA',
 'What country do you <strong>work</strong> in?':'work in country',
 'What US state or territory do you <strong>work</strong> in?':'work in state',
 'Start Date (UTC)':'CC',
 'Submit Date (UTC)':'CD',
 'Network ID':'CE'
}

# %%
#create Data Frame 
df_f5 = pd.DataFrame(f5)


df_f5.rename(columns=dict5,
          inplace=True)

# %%
list(df_f5.columns)
# Out:
# ['NO',
#  'Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'B',
#  'C',
#  'D',
#  'formally_discusse_employer',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'talking_to_coworker',
#  'supervisor',
#  'discussed_with_employer',
#  'E',
#  'issue_discussing',
#  'discusssed_coworkers',
#  'F',
#  'G',
#  'I',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'Medical_Insurence',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'impact_on_Productivity',
#  'O',
#  'P',
#  'tech_company',
#  'Q',
#  'Mental_health_Aware',
#  'R',
#  'S',
#  'T',
#  'U',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'AC',
#  'AD',
#  'AE',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'AF',
#  'AG',
#  'AH',
#  'AI',
#  'AJ',
#  'AK',
#  'AL',
#  'AM',
#  'AN',
#  'AO',
#  'AP',
#  'AQ',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AV',
#  'AW',
#  'AX',
#  'AY',
#  'AZ',
#  'BA',
#  'BB',
#  'BC',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
# ...

# %% [markdown]
# **Save the data in Local File (2017 File)**

# %%
#Export the DataFrame file in CSV file 2017

df_f5.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2017.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.6 2019 data on Mental Health

# %%
#import 2019 csv file in jupyter through pandas

f6 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2019.csv')

f6.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
# ...

# %%
list(f6.columns)
# Out:
# ['*Are you self-employed?*',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
dict6 = {'*Are you self-employed?*':'Self_Employed',
 'How many employees does your company or organization have?':'No_of_Employees',
 'Is your employer primarily a tech company/organization?':'Tech_Company',
 'Is your primary role within your company related to tech/IT?':'A',
 'Does your employer provide mental health benefits as part of healthcare coverage?':'B',
 'Do you know the options for mental health care available under your employer-provided health coverage?':'C',
 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':'formally_discusse_employer',
 'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':'Seek_Help',
 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?':'anonymity',
 'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':'Medical_Leave',
 'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':'talking_to_coworker',
 'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':'supervisor',
 'Have you ever discussed your mental health with your employer?':'discussed_with_employer',
 'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.':'D',
 'Would you feel comfortable discussing a mental health issue with your coworkers?':'issue_discussing',
 'Have you ever discussed your mental health with coworkers?':'E',
 'Describe the conversation with coworkers you had about your mental health including their reactions.':'F',
 "Have you ever had a coworker discuss their or another coworker's mental health with you?":'G',
 'Describe the conversation your coworker had with you about their mental health (please do not use names).':'I',
 'Overall, how much importance does your employer place on physical health?':'physical_health_importance',
 'Overall, how much importance does your employer place on mental health?':'Mental_health_importance',
 'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?':'Medical_Insurence',
 'Do you know local or online resources to seek help for a mental health issue?':'J',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?':'K',
 'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?':'L',
 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?':'M',
 'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?':'N',
 'Do you believe your productivity is ever affected by a mental health issue?':'impact_on_Productivity',
 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?':'O',
 '*Do you have previous employers?*':'P',
 'Was your employer primarily a tech company/organization?':'tech_company',
 'Have your previous employers provided mental health benefits?':'Q',
 'Were you aware of the options for mental health care provided by your previous employers?':'Mental_health_Aware',
 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':'R',
 'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':'S',
 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':'T',
 'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':'U',
 'Would you have been willing to discuss your mental health with your direct supervisor(s)?':'V',
 'Did you ever discuss your mental health with your previous employer?':'W',
 'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.':'X',
 'Would you have been willing to discuss your mental health with your coworkers at previous employers?':'Y',
 'Did you ever discuss your mental health with a previous coworker(s)?':'Z',
 'Describe the conversation you had with your previous coworkers about your mental health including their reactions.':'AA',
 "Did you ever have a previous coworker discuss their or another coworker's mental health with you?":'AB',
 'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':'AC',
 'Overall, how much importance did your previous employer place on physical health?':'AD',
 'Overall, how much importance did your previous employer place on mental health?':'AE',
 'Do you *currently* have a mental health disorder?':'have_a_mental_Health',
 'Have you ever been *diagnosed* with a mental health disorder?':'treated_Mental_Health(Diagnosed)',
 '*What disorder(s) have you been diagnosed with?*':'AF',
 '*If possibly, what disorder(s) do you believe you have?*':'AG',
 '*If so, what disorder(s) were you diagnosed with?*':'AI',
 'Have you had a mental health disorder in the past?':'Past_mental_Health',
 'Have you ever sought treatment for a mental health disorder from a mental health professional?':'Treatment',
 'Do you have a family history of mental illness?':'family_history',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*':'before_Interfere_in_work',
 'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*':'after_Interfere_in_work',
 'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':'Stress_Syndromes',
 'How willing would you be to share with friends and family that you have a mental illness?':'share_with_friends and family',
 'Would you be willing to bring up a physical health issue with a potential employer in an interview?':'a physical potential',
 'Why or why not?':'AJ',
 'Would you bring up your *mental* health with a potential employer in an interview?':'a mental potential',
 'Why or why not?.1':'AK',
 'Are you openly identified at work as a person with a mental health issue?':'openly_identify',
 'Has being identified as a person with a mental health issue affected your career?':'AL',
 'How has it affected your career?':'AM',
 'If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?':'co-workers reaction',
 'Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?':'unsupportive_workplace',
 'Describe the circumstances of the badly handled or unsupportive response.':'AN',
 'Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?':'supportive_workplace',
 'Describe the circumstances of the supportive or well handled response.':'AO',
 'Overall, how well do you think the tech industry supports employees with mental health issues?':'tech industry support',
 'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.':'AP',
 'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.':'AQ',
 'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)':'talk about experience',
 'What is your age?':'Age',
 'What is your gender?':'Gender',
 'What country do you *live* in?':'Country',
 'What US state or territory do you *live* in?':'State',
 'What is your race?':'race',
 'What country do you *work* in?':'work in country',
 'What US state or territory do you *work* in?':'work in state'
    }

# %%
#create Data Frame 
df_f6 = pd.DataFrame(f6)


df_f6.rename(columns=dict6,
          inplace=True)

# %%
list(df_f6.columns)
# Out:
# ['Self_Employed',
#  'No_of_Employees',
#  'Tech_Company',
#  'A',
#  'B',
#  'C',
#  'formally_discusse_employer',
#  'Seek_Help',
#  'anonymity',
#  'Medical_Leave',
#  'talking_to_coworker',
#  'supervisor',
#  'discussed_with_employer',
#  'D',
#  'issue_discussing',
#  'E',
#  'F',
#  'G',
#  'I',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'Medical_Insurence',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'impact_on_Productivity',
#  'O',
#  'P',
#  'tech_company',
#  'Q',
#  'Mental_health_Aware',
#  'R',
#  'S',
#  'T',
#  'U',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z',
#  'AA',
#  'AB',
#  'AC',
#  'AD',
#  'AE',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'AF',
#  'AG',
#  'AI',
#  'Past_mental_Health',
#  'Treatment',
#  'family_history',
#  'before_Interfere_in_work',
#  'after_Interfere_in_work',
#  'Stress_Syndromes',
#  'share_with_friends and family',
#  'a physical potential',
#  'AJ',
#  'a mental potential',
#  'AK',
# ...

# %% [markdown]
# **Save the data in Local File (2019 File)**

# %%
#Export the DataFrame file in CSV file 2019

df_f6.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2019.csv',index=False)

# %% [markdown]
# -------------------------------------------------------------------------------
# ### 1.7 2014 data on Mental Health

# %%
#import 2014 csv file in jupyter through pandas

f7 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\survey 2014.csv')

f7.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
list(f7.columns)
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %%
dict7 = {
 'state':'State',
 'self_employed':'Self_Employed',
 'treatment':'Treatment',
 'work_interfere':'after_Interfere_in_work',
 'no_employees':'No_of_Employees',
 'tech_company':'Tech_Company',
 'care_options':'Medical_Insurence',
 'leave':'Medical_Leave',
 'coworkers':'discusssed_coworkers',
 'mental_health_interview':'a mental potential',
 'phys_health_interview':'a mental potential',
 }

# %%
#create Data Frame 
df_f7 = pd.DataFrame(f7)


df_f7.rename(columns=dict7,
          inplace=True)

# %%
list(df_f7.columns)
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'State',
#  'Self_Employed',
#  'family_history',
#  'Treatment',
#  'after_Interfere_in_work',
#  'No_of_Employees',
#  'remote_work',
#  'Tech_Company',
#  'benefits',
#  'Medical_Insurence',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'Medical_Leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'discusssed_coworkers',
#  'supervisor',
#  'a mental potential',
#  'a mental potential',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %% [markdown]
# **Save the data in Local File (2014 File)**

# %%
#Export the DataFrame file in CSV file 2014

df_f7.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\Mental Health in Tech Survey 2014.csv',index=False)
