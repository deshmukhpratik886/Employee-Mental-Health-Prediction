# %% [markdown]
# # Data Preprocessing
# ## 3. Merging the Files
# Import the Library

# %%
import pandas as pd

# %% [markdown]
# ### 3.1 Import file for Merging (2017 file)

# %%
#import 2017 csv file in jupyter through pandas

M1 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2017.csv')
M1.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company formally_discusse_employer  \
# 0              0         100-500          1.0                         No
# 1              0         100-500          1.0                         No
# 2              0            6-25          1.0               I don't know
# 3              0  More than 1000          1.0               I don't know
# 4              1            Null         Null                       Null
#
#    seeking help     anonymity Medical_Leave             talking_to_coworker  \
# 0  I don't know  I don't know  I don't know  Same level of comfort for each
# 1            No  I don't know  I don't know  Same level of comfort for each
# 2            No           Yes     Difficult  Same level of comfort for each
# 3  I don't know           Yes     Difficult  Same level of comfort for each
# 4          Null          Null          Null                            Null
#
#   supervisor discussed_with_employer  ... supportive workplace  \
# ...

# %% [markdown]
# ###  3.2 Import file for Merging (2018 file)

# %%
#import 2018 csv file in jupyter through pandas

M2 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2018.csv')
M2.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company formally_discusse_employer  \
# 0              0  More than 1000          1.0                        Yes
# 1              0  More than 1000          1.0                         No
# 2              0            6-25          0.0                         No
# 3              0            6-25          1.0                         No
# 4              0          26-100          1.0                        Yes
#
#    seeking help     anonymity               Medical_Leave  \
# 0           Yes           Yes          Somewhat difficult
# 1  I don't know  I don't know          Somewhat difficult
# 2            No  I don't know               Somewhat easy
# 3            No  I don't know  Neither easy nor difficult
# 4           Yes           Yes               Somewhat easy
#
#               talking_to_coworker supervisor discussed_with_employer  ...  \
# 0                 Physical health         No                     1.0  ...
# ...

# %% [markdown]
# ### 3.3 Import file for Merging (2020 file)

# %%
#import 2020 csv file in jupyter through pandas

M3 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2020.csv')
M3.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company formally_discusse_employer  \
# 0              1            Null         Null                       Null
# 1              1            Null         Null                       Null
# 2              1            Null         Null                       Null
# 3              1            Null         Null                       Null
# 4              1            Null         Null                       Null
#
#   seeking help anonymity Medical_Leave talking_to_coworker supervisor  \
# 0         Null      Null          Null                Null       Null
# 1         Null      Null          Null                Null       Null
# 2         Null      Null          Null                Null       Null
# 3         Null      Null          Null                Null       Null
# 4         Null      Null          Null                Null       Null
#
#   discussed_with_employer  ... supportive workplace tech industry support  \
# ...

# %% [markdown]
# ### 3.4 Import file for Merging (2021 file)

# %%
#import 2021 csv file in jupyter through pandas

M4 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2021.csv')
M4.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company formally_discusse_employer  \
# 0              0          26-100          1.0                         No
# 1              0        500-1000          1.0                        Yes
# 2              0         100-500          1.0                         No
# 3              1            Null         Null                       Null
# 4              0  More than 1000          0.0                        Yes
#
#    seeking help     anonymity  Medical_Leave             talking_to_coworker  \
# 0  I don't know  I don't know      Very easy                 Physical health
# 1           Yes           Yes   I don't know                 Physical health
# 2  I don't know  I don't know  Somewhat easy  Same level of comfort for each
# 3          Null          Null           Null                            Null
# 4           Yes  I don't know      Difficult                 Physical health
#
# ...

# %% [markdown]
# ### 3.5 Import file for Merging (2014 file)

# %%
#import 2014 csv file in jupyter through pandas

M5 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\Mental Health in Tech Survey 2014.csv')
M5.head()
# Out:
#    Age  Gender         Country State Self_Employed family history Treatment  \
# 0   37  Female   United States    IL          Null             No       Yes
# 1   44       M   United States    IN          Null             No        No
# 2   32    Male          Canada  Null          Null             No        No
# 3   31    Male  United Kingdom  Null          Null            Yes       Yes
# 4   31    Male   United States    TX          Null             No        No
#
#   after_Interfere_in_work No_of_Employees remote_work  ... seeking help  \
# 0                   Often            6-25          No  ...          Yes
# 1                  Rarely  More than 1000          No  ...   Don't know
# 2                  Rarely            6-25          No  ...           No
# 3                   Often          26-100          No  ...           No
# 4                   Never         100-500         Yes  ...   Don't know
#
#     anonymity       Medical_Leave mental_health_consequence  \
# ...

# %% [markdown]
# ### 3.6 Import file for Merging (2016 file)

# %%
#import 2016 csv file in jupyter through pandas

M6 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\mental-heath-in-tech-2016_20161114.csv')
M6.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company  \
# 0              0          26-100          1.0
# 1              0            6-25          1.0
# 2              0            6-25          1.0
# 3              1            Null         Null
# 4              0            6-25          0.0
#
#                           Benefits formally_discusse_employer seeking help  \
# 0  Not eligible for coverage / N/A                         No           No
# 1                               No                        Yes          Yes
# 2                               No                         No           No
# 3                             Null                       Null         Null
# 4                              Yes                         No           No
#
#       anonymity               Medical_Leave mental_health_consequence  \
# 0  I don't know                   Very easy                        No
# 1           Yes               Somewhat easy                        No
# ...

# %% [markdown]
# ### 3.7 Import file for Merging (2019 file)

# %%
#import 2019 csv file in jupyter through pandas

M7 = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2019.csv')

M7.head()
# Out:
#    Self_Employed No_of_Employees Tech_Company formally_discusse_employer  \
# 0          False          26-100         True                        Yes
# 1          False          26-100         True                         No
# 2          False          26-100         True                         No
# 3          False         100-500         True                        Yes
# 4          False          26-100         True               I don't know
#
#    seeking help     anonymity       Medical_Leave  \
# 0           Yes  I don't know           Very easy
# 1           Yes           Yes        I don't know
# 2  I don't know  I don't know  Somewhat difficult
# 3           Yes           Yes           Very easy
# 4  I don't know  I don't know        I don't know
#
#               talking_to_coworker supervisor discussed_with_employer  ...  \
# 0                 Physical health        Yes                   False  ...
# ...

# %% [markdown]
# ### 3.8 Merge all Files

# %%
#Merge all file(2014,2016,2017,2018,2019,2020,2021)

Merge = pd.concat(
    map(pd.read_csv, ['G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\Mental Health in Tech Survey 2014.csv','G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\mental-heath-in-tech-2016_20161114.csv',
                     'G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2017.csv','G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2018.csv',
                     'G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2019.csv','G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2020.csv',
                     'G:\\DBDA\\DBDA project\\Project data\\Project data\\Complete record of employee mental health from 2014-2022\\OSMI Mental Health in Tech Survey 2021.csv']), ignore_index=True)

# %% [markdown]
# **Show Merge File data**

# %%
print(Merge)
# Out:
#      Age  Gender         Country State Self_Employed family history Treatment  \
# 0     37  Female   United States    IL          Null             No       Yes
# 1     44       M   United States    IN          Null             No        No
# 2     32    Male          Canada  Null          Null             No        No
# 3     31    Male  United Kingdom  Null          Null            Yes       Yes
# 4     31    Male   United States    TX          Null             No        No
# ...   ..     ...             ...   ...           ...            ...       ...
# 4523  33    Male         Germany  Null             0   I don't know         1
# 4524  49    Male        Portugal  Null             0            Yes         0
# 4525  28    Null        Pakistan  Null             1             No         0
# 4526  26    Male           India  Null             1             No         0
# 4527  38    male        Slovenia  Null             0             No         1
#
# ...

# %% [markdown]
# **Show Merge file cloumns Name**

# %%
list(Merge.columns)
# Out:
# ['Age',
#  'Gender',
#  'Country',
#  'State',
#  'Self_Employed',
#  'family history',
#  'Treatment',
#  'after_Interfere_in_work',
#  'No_of_Employees',
#  'remote_work',
#  'Tech_Company',
#  'benefits',
#  'Medical_Insurence',
#  'wellness_program',
#  'seeking help',
#  'anonymity',
#  'Medical_Leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'talking_to_coworker',
#  'supervisor',
#  'a mental potential',
#  'a physical potential',
#  'mental_vs_physical',
#  'Benefits',
#  'formally_discusse_employer',
#  'discussed_with_employer',
#  'issue_discussing',
#  'obs_consequence',
#  'seek_help',
#  'share with friends and family',
#  'unsupportive workplace',
#  'Past_mental_Health',
#  'have_a_mental_Health',
#  'treated_Mental_Health(Diagnosed)',
#  'before_Interfere_in_work',
#  'work in country',
#  'work in state',
#  'discusssed_coworkers',
#  'physical_health_importance',
#  'Mental_health_importance',
#  'impact_on_Productivity',
# ...

# %% [markdown]
# **Show Number of rows and columns**

# %%
Merge.shape
# Out:
# (4528, 51)

# %% [markdown]
# Check the Null values

# %%
Merge.notnull()
# Out:
#        Age  Gender  Country  State  Self_Employed  family history  Treatment  \
# 0     True    True     True   True           True            True       True
# 1     True    True     True   True           True            True       True
# 2     True    True     True   True           True            True       True
# 3     True    True     True   True           True            True       True
# 4     True    True     True   True           True            True       True
# ...    ...     ...      ...    ...            ...             ...        ...
# 4523  True    True     True   True           True            True       True
# 4524  True    True     True   True           True            True       True
# 4525  True    True     True   True           True            True       True
# 4526  True    True     True   True           True            True       True
# 4527  True    True     True   True           True            True       True
#
# ...

# %% [markdown]
# Show first 5 row from the data

# %%
Merge.head()
# Out:
#   Age  Gender         Country State Self_Employed family history Treatment  \
# 0  37  Female   United States    IL          Null             No       Yes
# 1  44       M   United States    IN          Null             No        No
# 2  32    Male          Canada  Null          Null             No        No
# 3  31    Male  United Kingdom  Null          Null            Yes       Yes
# 4  31    Male   United States    TX          Null             No        No
#
#   after_Interfere_in_work No_of_Employees remote_work  ...  \
# 0                   Often            6-25          No  ...
# 1                  Rarely  More than 1000          No  ...
# 2                  Rarely            6-25          No  ...
# 3                   Often          26-100          No  ...
# 4                   Never         100-500         Yes  ...
#
#   impact_on_Productivity tech_company Mental_health_Aware Stress_Syndromes  \
# 0                    NaN          NaN                 NaN              NaN
# ...

# %% [markdown]
# Fill Null Values

# %%
Merge.fillna("Null",inplace=True)

# %% [markdown]
# Check Null values after Filling

# %%
Merge.notnull()
# Out:
#        Age  Gender  Country  State  Self_Employed  family history  Treatment  \
# 0     True    True     True   True           True            True       True
# 1     True    True     True   True           True            True       True
# 2     True    True     True   True           True            True       True
# 3     True    True     True   True           True            True       True
# 4     True    True     True   True           True            True       True
# ...    ...     ...      ...    ...            ...             ...        ...
# 4523  True    True     True   True           True            True       True
# 4524  True    True     True   True           True            True       True
# 4525  True    True     True   True           True            True       True
# 4526  True    True     True   True           True            True       True
# 4527  True    True     True   True           True            True       True
#
# ...

# %%
Merge.head()
# Out:
#   Age  Gender         Country State Self_Employed family history Treatment  \
# 0  37  Female   United States    IL          Null             No       Yes
# 1  44       M   United States    IN          Null             No        No
# 2  32    Male          Canada  Null          Null             No        No
# 3  31    Male  United Kingdom  Null          Null            Yes       Yes
# 4  31    Male   United States    TX          Null             No        No
#
#   after_Interfere_in_work No_of_Employees remote_work  ...  \
# 0                   Often            6-25          No  ...
# 1                  Rarely  More than 1000          No  ...
# 2                  Rarely            6-25          No  ...
# 3                   Often          26-100          No  ...
# 4                   Never         100-500         Yes  ...
#
#   impact_on_Productivity tech_company Mental_health_Aware Stress_Syndromes  \
# 0                   Null         Null                Null             Null
# ...

# %% [markdown]
# ### 3.9 Final Merge Fill Save in Local data

# %%
#Export the Merge file in Local CSV file  

Merge.to_csv('G:\\DBDA\\DBDA project\\Project data\\Merge all files 2.csv',index=False)
