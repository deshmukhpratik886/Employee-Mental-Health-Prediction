# %% [markdown]
# # Data Preprocessing
# ## 4. Handling the Outliers

# %%
# Importing library for data processing

import pandas as pd

# %% [markdown]
# ### 4.1 Import Merge file

# %%
# Reading the dataset (merged dataset of all files)

final_merged_data = pd.read_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Final DataSet.csv')

# %%
# Look at the data

final_merged_data.head()
# Out:
#   Age  Gender         Country State Self_Employed family history Treatment  \
# 0  37  Female   United States    IL          Null             No       Yes
# 1  44       M   United States    IN          Null             No        No
# 2  32    Male          Canada  Null          Null             No        No
# 3  31    Male  United Kingdom  Null          Null            Yes       Yes
# 4  31    Male   United States    TX          Null             No        No
#
#   after_Interfere_in_work No_of_Employees remote_work  ...  \
# 0                   Often            6-25          No  ...
# 1                  Rarely  More than 1000          No  ...
# 2                  Rarely            6-25          No  ...
# 3                   Often          26-100          No  ...
# 4                   Never         100-500         Yes  ...
#
#   impact_on_Productivity tech_company Mental_health_Aware Stress_Syndromes  \
# 0                   Null         Null                Null             Null
# ...

# %%
# Shape of the data

final_merged_data.shape
# Out:
# (4528, 51)

# %% [markdown]
# **To Check all infornation of data**

# %%
final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528 entries, 0 to 4527
# Data columns (total 51 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               4528 non-null   object
#  1   Gender                            4528 non-null   object
#  2   Country                           4528 non-null   object
#  3   State                             4528 non-null   object
#  4   Self_Employed                     4528 non-null   object
#  5   family history                    4528 non-null   object
#  6   Treatment                         4528 non-null   object
#  7   after_Interfere_in_work           4528 non-null   object
#  8   No_of_Employees                   4528 non-null   object
#  9   remote_work                       4528 non-null   object
#  10  Tech_Company                      4528 non-null   object
# ...

# %%
#Show Describtion of data
final_merged_data.describe()
# Out:
#          Age Gender                   Country State Self_Employed  \
# count   4528   4528                      4528  4528          4528
# unique   117    187                        88    94             7
# top       30   Male  United States of America  Null             0
# freq     220   1972                      1967  1818          2419
#
#        family history Treatment after_Interfere_in_work No_of_Employees  \
# count            4528      4528                    4528            4528
# unique              3         6                       6               9
# top               Yes         1                   Often  More than 1000
# freq             1978      1704                    1452            1032
#
#        remote_work  ... impact_on_Productivity tech_company  \
# count         4528  ...                   4528         4528
# unique           6  ...                      5            5
# top           Null  ...                   Null         Null
# ...

# %%
# make dataframe of it

df_final_merged_data = pd.DataFrame(final_merged_data)

# %%
df_final_merged_data
# Out:
#      Age  Gender         Country State Self_Employed family history Treatment  \
# 0     37  Female   United States    IL          Null             No       Yes
# 1     44       M   United States    IN          Null             No        No
# 2     32    Male          Canada  Null          Null             No        No
# 3     31    Male  United Kingdom  Null          Null            Yes       Yes
# 4     31    Male   United States    TX          Null             No        No
# ...   ..     ...             ...   ...           ...            ...       ...
# 4523  33    Male         Germany  Null             0   I don't know         1
# 4524  49    Male        Portugal  Null             0            Yes         0
# 4525  28    Null        Pakistan  Null             1             No         0
# 4526  26    Male           India  Null             1             No         0
# 4527  38    male        Slovenia  Null             0             No         1
#
# ...

# %% [markdown]
# ### 4.2 Checking the Outliers and Removing in Age Column

# %%
# Data Preparation

# Cleaning the Dataset by removing outliers

# There are values in this column that doesn't make sense

# pick the age column first

# checking the unique values in the col

df_final_merged_data['Age'].unique()
# Out:
# array(['37', '44', '32', '31', '33', '35', '39', '42', '23', '29', '36',
#        '27', '46', '41', '34', '30', '40', '38', '50', '24', '18', '28',
#        '26', '22', '19', '25', '45', '21', '-29', '43', '56', '60', '54',
#        '329', '55', '99999999999', '48', '20', '57', '58', '47', '62',
#        '51', '65', '49', '-1726', '5', '53', '61', '8', '11', '-1', '72',
#        '52', '17', '63', '99', '323', '3', '66', '59', '15', '74', '70',
#        '27.0', '31.0', '36.0', '22.0', '52.0', '30.0', '38.0', '35.0',
#        '40.0', '23.0', '34.0', '28.0', '53.0', '21.0', '18.0', '37.0',
#        '25.0', '33.0', '66.0', '32.0', '46.0', '29.0', '39.0', '42.0',
#        '43.0', '47.0', '64.0', '45.0', '54.0', '61.0', '26.0', '44.0',
#        '50.0', '24.0', '57.0', '48.0', '41.0', '20.0', '49.0', '62.0',
#        '51.0', '60.0', '58.0', '59.0', '67.0', '56.0', '55.0', 'Null',
#        '67', '64', '0', '1', '223'], dtype=object)

# %%
# checking the position of the outliers

first = df_final_merged_data.loc[143] 
print(first)
# Out:
# Age                                            -29
# Gender                                        Male
# Country                              United States
# State                                           MN
# Self_Employed                                   No
# family history                                  No
# Treatment                                       No
# after_Interfere_in_work                       Null
# No_of_Employees                     More than 1000
# remote_work                                    Yes
# Tech_Company                                    No
# benefits                                       Yes
# Medical_Insurence                               No
# wellness_program                        Don't know
# seeking help                                   Yes
# anonymity                               Don't know
# Medical_Leave                           Don't know
# mental_health_consequence                       No
# ...

# %%
# checking the position of the outliers

second = df_final_merged_data.loc[364] 
print(second)
# Out:
# Age                                           329
# Gender                                       Male
# Country                             United States
# State                                          OH
# Self_Employed                                  No
# family history                                 No
# Treatment                                     Yes
# after_Interfere_in_work                     Often
# No_of_Employees                              6-25
# remote_work                                   Yes
# Tech_Company                                  Yes
# benefits                                      Yes
# Medical_Insurence                             Yes
# wellness_program                               No
# seeking help                                   No
# anonymity                              Don't know
# Medical_Leave                          Don't know
# mental_health_consequence                   Maybe
# phys_health_consequence                        No
# ...

# %%
# checking the position of the outliers

third = df_final_merged_data.loc[390] 
print(third)
# Out:
# Age                                    99999999999
# Gender                                         All
# Country                                   Zimbabwe
# State                                         Null
# Self_Employed                                  Yes
# family history                                 Yes
# Treatment                                      Yes
# after_Interfere_in_work                      Often
# No_of_Employees                                1-5
# remote_work                                     No
# Tech_Company                                   Yes
# benefits                                        No
# Medical_Insurence                              Yes
# wellness_program                                No
# seeking help                                    No
# anonymity                                       No
# Medical_Leave                       Very difficult
# mental_health_consequence                      Yes
# ...

# %%
# checking the position of the outliers

four = df_final_merged_data.loc[715] 
print(four)
# Out:
# Age                                              -1726
# Gender                                            male
# Country                                 United Kingdom
# State                                             Null
# Self_Employed                                       No
# family history                                      No
# Treatment                                          Yes
# after_Interfere_in_work                      Sometimes
# No_of_Employees                                 26-100
# remote_work                                         No
# Tech_Company                                        No
# benefits                                            No
# Medical_Insurence                                   No
# wellness_program                                    No
# seeking help                                        No
# anonymity                                   Don't know
# Medical_Leave                       Somewhat difficult
# ...

# %%
# checking the position of the outliers

five = df_final_merged_data.loc[1127] 
print(five)
# Out:
# Age                                            -1
# Gender                                          p
# Country                             United States
# State                                          AL
# Self_Employed                                 Yes
# family history                                Yes
# Treatment                                     Yes
# after_Interfere_in_work                     Often
# No_of_Employees                               1-5
# remote_work                                   Yes
# Tech_Company                                  Yes
# benefits                                      Yes
# Medical_Insurence                             Yes
# wellness_program                              Yes
# seeking help                                  Yes
# anonymity                                     Yes
# Medical_Leave                           Very easy
# mental_health_consequence                     Yes
# phys_health_consequence                       Yes
# ...

# %%
# checking the position of the outliers

six = df_final_merged_data.loc[1631] 
print(six)
# Out:
# Age                                                       99
# Gender                                                 Other
# Country                             United States of America
# State                                               Michigan
# Self_Employed                                              0
# family history                                           Yes
# Treatment                                                  1
# after_Interfere_in_work                                Often
# No_of_Employees                                         6-25
# remote_work                                        Sometimes
# Tech_Company                                             1.0
# benefits                                                Null
# Medical_Insurence                                       Null
# wellness_program                                        Null
# seeking help                                    I don't know
# ...

# %%
# checking the position of the outliers

seven = df_final_merged_data.loc[1823] 
print(seven)
# Out:
# Age                                                      323
# Gender                                                  Male
# Country                             United States of America
# State                                                 Oregon
# Self_Employed                                              0
# family history                                           Yes
# Treatment                                                  0
# after_Interfere_in_work                 Not applicable to me
# No_of_Employees                                      100-500
# remote_work                                        Sometimes
# Tech_Company                                             1.0
# benefits                                                Null
# Medical_Insurence                                       Null
# wellness_program                                        Null
# seeking help                                    I don't know
# ...

# %%
# checking the position of the outliers

eight = df_final_merged_data.loc[3979] 
print(eight)
# Out:
# Age                                                              0
# Gender                                                        male
# Country                                   United States of America
# State                                                     Nebraska
# Self_Employed                                                False
# family history                                                  No
# Treatment                                                    False
# after_Interfere_in_work                       Not applicable to me
# No_of_Employees                                           500-1000
# remote_work                                                   Null
# Tech_Company                                                 False
# benefits                                                      Null
# Medical_Insurence                                             Null
# wellness_program                                              Null
# ...

# %%
# checking the position of the outliers

nine = df_final_merged_data.loc[4223] 
print(nine)
# Out:
# Age                                                               1
# Gender                                                         Null
# Country                                                       Japan
# State                                                          Null
# Self_Employed                                                     1
# family history                                                  Yes
# Treatment                                                         1
# after_Interfere_in_work                                       Never
# No_of_Employees                                                Null
# remote_work                                                    Null
# Tech_Company                                                   Null
# benefits                                                       Null
# Medical_Insurence                                               1.0
# wellness_program                                               Null
# ...

# %%
# checking the position of the outliers

ten = df_final_merged_data.loc[4435] 
print(ten)
# Out:
# Age                                                           223
# Gender                                                       Null
# Country                                  United States of America
# State                                                     Alabama
# Self_Employed                                                   0
# family history                                                Yes
# Treatment                                                       1
# after_Interfere_in_work                                     Never
# No_of_Employees                                            01-May
# remote_work                                                  Null
# Tech_Company                                                  0.0
# benefits                                                     Null
# Medical_Insurence                                            Null
# wellness_program                                             Null
# ...

# %%
# creating list of indexes having outliers

list1=[143,364,390,715,1127,1631,1823,3979,4223,4435]

# %%
# Removing values which can't be changed that is above list

df_final_merged_data.drop(list1,inplace=True)

# %%
# checking the size of the dataframe which is reduced by ten as we have removed 10 rows having outliers

df_final_merged_data.shape
# Out:
# (4518, 51)

# %% [markdown]
# **Show data after removing outliers**

# %%
df_final_merged_data['Age'].unique()
# Out:
# array(['37', '44', '32', '31', '33', '35', '39', '42', '23', '29', '36',
#        '27', '46', '41', '34', '30', '40', '38', '50', '24', '18', '28',
#        '26', '22', '19', '25', '45', '21', '43', '56', '60', '54', '55',
#        '48', '20', '57', '58', '47', '62', '51', '65', '49', '5', '53',
#        '61', '8', '11', '72', '52', '17', '63', '3', '66', '59', '15',
#        '74', '70', '27.0', '31.0', '36.0', '22.0', '52.0', '30.0', '38.0',
#        '35.0', '40.0', '23.0', '34.0', '28.0', '53.0', '21.0', '18.0',
#        '37.0', '25.0', '33.0', '66.0', '32.0', '46.0', '29.0', '39.0',
#        '42.0', '43.0', '47.0', '64.0', '45.0', '54.0', '61.0', '26.0',
#        '44.0', '50.0', '24.0', '57.0', '48.0', '41.0', '20.0', '49.0',
#        '62.0', '51.0', '60.0', '58.0', '59.0', '67.0', '56.0', '55.0',
#        'Null', '67', '64'], dtype=object)

# %% [markdown]
# ### 4.3 Checking the Outliers, MisMatch Values and Make it proper from Gender column

# %%
# pick the gender col

# Gender column consist of lots of inconsistent values 

# printing unique values for gender col

print(df_final_merged_data['Gender'].unique())
# Out:
# ['Female' 'M' 'Male' 'male' 'female' 'm' 'Male-ish' 'maile' 'Trans-female'
#  'Cis Female' 'F' 'something kinda male?' 'Cis Male' 'Woman' 'f' 'Mal'
#  'Male (CIS)' 'queer/she/they' 'non-binary' 'Femake' 'woman' 'Make' 'Nah'
#  'Enby' 'fluid' 'Genderqueer' 'Female ' 'Androgyne' 'Agender'
#  'cis-female/femme' 'Guy (-ish) ^_^' 'male leaning androgynous' 'Male '
#  'Man' 'Trans woman' 'msle' 'Neuter' 'Female (trans)' 'queer'
#  'Female (cis)' 'Mail' 'cis male' 'A little about you' 'Malr' 'femail'
#  'Cis Man' 'ostensibly male, unsure what that really means'
#  'I identify as female.' 'female ' 'Bigender' 'Female assigned at birth '
#  'man' 'fm' 'Cis female ' 'Transitioned, M2F' 'Genderfluid (born female)'
#  'Other/Transfeminine' 'Female or Multi-Gender Femme' 'female/woman'
#  'Cis male' 'Male.' 'Androgynous' 'male 9:1 female, roughly' 'Null'
#  'Male (cis)' 'nb masculine' 'Cisgender Female' 'Sex is male'
#  'none of your business' 'genderqueer' 'Human' 'Genderfluid'
# ...

# %%
# Changing all values to lowercase

df_final_merged_data["Gender"] = df_final_merged_data["Gender"].str.lower()

# %% [markdown]
# Show the unique and mismatch values

# %%
print(df_final_merged_data['Gender'].unique())
# Out:
# ['female' 'm' 'male' 'male-ish' 'maile' 'trans-female' 'cis female' 'f'
#  'something kinda male?' 'cis male' 'woman' 'mal' 'male (cis)'
#  'queer/she/they' 'non-binary' 'femake' 'make' 'nah' 'enby' 'fluid'
#  'genderqueer' 'female ' 'androgyne' 'agender' 'cis-female/femme'
#  'guy (-ish) ^_^' 'male leaning androgynous' 'male ' 'man' 'trans woman'
#  'msle' 'neuter' 'female (trans)' 'queer' 'female (cis)' 'mail'
#  'a little about you' 'malr' 'femail' 'cis man'
#  'ostensibly male, unsure what that really means' 'i identify as female.'
#  'bigender' 'female assigned at birth ' 'fm' 'cis female '
#  'transitioned, m2f' 'genderfluid (born female)' 'other/transfeminine'
#  'female or multi-gender femme' 'female/woman' 'male.' 'androgynous'
#  'male 9:1 female, roughly' 'null' 'nb masculine' 'cisgender female'
#  'sex is male' 'none of your business' 'human' 'genderfluid'
#  'genderqueer woman' 'mtf' 'dude'
# ...

# %% [markdown]
# **Group the all mismatch values**

# %%
# Making gender-groups to classify all values


male_str = ["male", "m", "male-ish", "maile", "mal", "male (cis)", "make", "male ",
            "man","msle", "mail", "malr","cis man", "Cis Male", "cis male",'male.',
            'nb masculine','sex is male','mtf',"i'm a man why didn't you make this a drop down question. you should of asked sex? and i would of answered yes please. seriously how much text can this take? ",
            'm|','cis-male','cis hetero male',"male (hey this is the tech industry you're talking about)",
            'male, cis','ostensibly male','male, born with xy chromosoms',
            'malel','cisgender male','let\'s keep it simple and say "male"',
            'identify as male','masculine','cishet male','i have a penis',
            'masculino','male/he/him','cis-het male','cis male ' ]



trans_str = ["trans-female", "something kinda male?", "queer/she/they",
             "non-binary","nah", "all", "enby", "fluid", "genderqueer", "androgyne", 
             "agender", "male leaning androgynous", "guy (-ish) ^_^", "trans woman", "neuter", 
             "female (trans)", "queer", "ostensibly male, unsure what that really means",
             'bigender','other/transfeminine','androgynous','genderfluid','nonbinary','female-bodied; no feelings about gender',
             'transgender woman','uhhhhhhhhh fem genderqueer?','agender/genderfluid','non binary',
             'genderqueer demigirl','genderqueer/non-binary','transfeminine',
             'male (or female, or both)','trans man','transgender','female/gender non-binary.',
             'demiguy','trans female','she/her/they/them','other',
             'nonbinary/femme','gender non-conforming woman','agender trans woman',
             'trans non-binary/genderfluid','non-binary and gender fluid','mostly male',
             'afab non-binary','non-binary/agender','male/genderqueer',
             'male (trans, ftm)','male/androgynous ' ]           




female_str = ["cis female", "f", "female", "woman",  "femake", "female ","cis-female/femme", 
              "female (cis)", "femail",'i identify as female.','female assigned at birth ',
              'fm','cis female ','genderfluid (born female)','female/woman','female or multi-gender femme',
              'cisgender female','genderqueer woman','fem','female (props for making this a freeform field, though)',
              ' female','cis-woman','genderflux demi-girl','femalw','my sex is female.','female (cisgender)','female (cis) ',
              'woman-identified',
              'cis-female','female-ish','i identify as female','*shrug emoji* (f)','cis woman',
                 "cisgendered woman",'female-identified','femmina','femile','female, she/her' ]

# %% [markdown]
# **Replace the mismatch value in meaningfull data**

# %%
# Changing groups into three categories

for (row, col) in df_final_merged_data.iterrows():

    if (col.Gender) in male_str:
        df_final_merged_data['Gender'].replace(to_replace=col.Gender, value='male', inplace=True)

    if (col.Gender) in female_str:
        df_final_merged_data['Gender'].replace(to_replace=col.Gender, value='female', inplace=True)

    if (col.Gender) in trans_str:
        df_final_merged_data['Gender'].replace(to_replace=col.Gender, value='trans', inplace=True)

        
# Getting rid of unnnecessary values

stk_list = ['a little about you', 'p','none of your business','human','dude',
            'unicorn','cisdude','afab','god king of the valajar',
            'sometimes','contextual','\\-','none','swm','nb','questioning','rr',
            '43','i am a wookie','b','homem cis','transitioned, m2f',
            'male 9:1 female, roughly', 'f, cisgender']

df_final_merged_data = df_final_merged_data[~df_final_merged_data['Gender'].isin(stk_list)]

# %%
# Values after cleaning gender col

df_final_merged_data["Gender"].value_counts()
# Out:
# male      3227
# female    1150
# trans       87
# null        26
# Name: Gender, dtype: int64

# %% [markdown]
# Showing Proper and Meaningfull data

# %%
df_final_merged_data['Gender'].unique()
# Out:
# array(['female', 'male', 'trans', 'null'], dtype=object)

# %% [markdown]
# ### 4.4 Handling Mismatch data from No_of_Employees column

# %%
# now pick No_of_Employees col and remove or replace outliers

# first check the unique values in this col

df_final_merged_data['No_of_Employees'].unique()
# Out:
# array(['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000',
#        'Null', 'Jun-25', '01-May'], dtype=object)

# %% [markdown]
# **Grouping the mismatch data**

# %%
# Making groups to classify all values

jun_str = ["Jun-25"]
may_str = ["01-May"]

# %% [markdown]
# **Change in Meaningfull data**

# %%
# Changing groups into two categories

for (row, col) in df_final_merged_data.iterrows():

    if (col.No_of_Employees) in jun_str:
        df_final_merged_data['No_of_Employees'].replace(to_replace=col.No_of_Employees, value='6-25', inplace=True)

    if (col.No_of_Employees) in may_str:
        df_final_merged_data['No_of_Employees'].replace(to_replace=col.No_of_Employees, value='1-5', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\2248711756.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['No_of_Employees'].replace(to_replace=col.No_of_Employees, value='6-25', inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\2248711756.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['No_of_Employees'].replace(to_replace=col.No_of_Employees, value='1-5', inplace=True)

# %%
df_final_merged_data['No_of_Employees'].unique()
# Out:
# array(['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000',
#        'Null'], dtype=object)

# %%
# Values after cleaning No_of_Employees col

df_final_merged_data["No_of_Employees"].value_counts()
# Out:
# More than 1000    1024
# 26-100             866
# 100-500            828
# 6-25               704
# Null               540
# 500-1000           274
# 1-5                254
# Name: No_of_Employees, dtype: int64

# %% [markdown]
# ### 4.5 Make data in proper and Meaningfull

# %%
# now pick Self_Employed col and remove or replace outliers

# first check the unique values in this col


df_final_merged_data['Self_Employed'].unique()
# Out:
# array(['Null', 'Yes', 'No', '0', '1', 'False', 'True'], dtype=object)

# %% [markdown]
# **Grouping the data**

# %%
# Making groups to classify all values

zero_str = ["0"]
one_str = ["1"]

# %% [markdown]
# **Change in Proper and Meaningfull data**

# %%
# Changing groups into two categories

for (row, col) in df_final_merged_data.iterrows():

    if (col.Self_Employed) in zero_str:
        df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='False', inplace=True)

    if (col.Self_Employed) in one_str:
        df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='True', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\3932324685.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='False', inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\3932324685.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='True', inplace=True)

# %%
# Values after cleaning

df_final_merged_data['Self_Employed'].value_counts()
# Out:
# False    2697
# No       1092
# True      540
# Yes       143
# Null       18
# Name: Self_Employed, dtype: int64

# %%
df_final_merged_data['Self_Employed'].unique()
# Out:
# array(['Null', 'Yes', 'No', 'False', 'True'], dtype=object)

# %%
# now pick Self_Employed col and remove or replace outliers

# first check the unique values in this col


df_final_merged_data['Self_Employed'].unique()


# Making groups to classify all values

no_str = ["No"]
yes_str = ["Yes"]

# %%
# Changing groups into two categories

for (row, col) in df_final_merged_data.iterrows():

    if (col.Self_Employed) in no_str:
        df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='False', inplace=True)

    if (col.Self_Employed) in yes_str:
        df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='True', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\243073202.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='True', inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\243073202.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_merged_data['Self_Employed'].replace(to_replace=col.Self_Employed, value='False', inplace=True)

# %%
# Values after cleaning

df_final_merged_data['Self_Employed'].value_counts()
# Out:
# False    3789
# True      683
# Null       18
# Name: Self_Employed, dtype: int64

# %%
print(df_final_merged_data)
# Out:
#      Age  Gender         Country State Self_Employed family history Treatment  \
# 0     37  female   United States    IL          Null             No       Yes
# 1     44    male   United States    IN          Null             No        No
# 2     32    male          Canada  Null          Null             No        No
# 3     31    male  United Kingdom  Null          Null            Yes       Yes
# 4     31    male   United States    TX          Null             No        No
# ...   ..     ...             ...   ...           ...            ...       ...
# 4523  33    male         Germany  Null         False   I don't know         1
# 4524  49    male        Portugal  Null         False            Yes         0
# 4525  28    null        Pakistan  Null          True             No         0
# 4526  26    male           India  Null          True             No         0
# 4527  38    male        Slovenia  Null         False             No         1
#
# ...

# %% [markdown]
# ### 4.6 Save the Clean data in Local file

# %%
#Export the Clean data in Local CSV file

df_final_merged_data.to_csv('G:\\DBDA\\DBDA project\\Project data\\Project data\\Final DataSet.csv',index=False)
